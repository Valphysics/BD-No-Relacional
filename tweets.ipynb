# %%
from pymongo import MongoClient
# This script connects to a MongoDB database and retrieves documents from the 'Tweets' collection.

client = MongoClient('mongodb+srv://valphysics:Gatobarato1@cluster0.bus3hra.mongodb.net/')
filter={ 
    {'negativereason': 'Bad Flight'} #selec tweets con uno de los motivos
    }

result = client['AnalisisdeDatos']['Tweets'].find(
  filter=filter
)

# %%
import pprint #trae los datos con la estructura original
pp=pprint.PrettyPrinter(indent=4)
for doc in result:
  pp.pprint(doc)
  print("\n")
# Out:
# {   '_id': ObjectId('68770bcab04d7a911987af47'),
#     'airline': 'Virgin America',
#     'airline_sentiment': 'negative',
#     'airline_sentiment_confidence': Decimal128('1.0'),
#     'name': 'jnardino',
#     'negativereason': 'Bad Flight',
#     'negativereason_confidence': Decimal128('0.7033'),
#     'retweet_count': 0,
#     'text': "@VirginAmerica it's really aggressive to blast obnoxious "
#             '"entertainment" in your guests\' faces &amp; they have little '
#             'recourse',
#     'tweet_created': '2015-02-24 11:15:36 -0800',
#     'tweet_id': 570301031407624196,
#     'user_timezone': 'Pacific Time (US & Canada)'}
#
#
# {   '_id': ObjectId('68770bcab04d7a911987af55'),
#     'airline': 'Virgin America',
#     'airline_sentiment': 'negative',
#     'airline_sentiment_confidence': Decimal128('1.0'),
#     'name': 'heatherovieda',
#     'negativereason': 'Bad Flight',
#     'negativereason_confidence': Decimal128('1.0'),
#     'retweet_count': 0,
# ...

# %%
# Example filter to retrieve tweets with at least one retweet
filter={
    'retweet_count': {"$gte": 44}}

result = client['AnalisisdeDatos']['Tweets'].find(
  filter=filter)

pp=pprint.PrettyPrinter(indent=4)
for doc in result:
  pp.pprint(doc)
  print("\n")
# Out:
# {   '_id': ObjectId('68770cfab04d7a911987dc90'),
#     'airline': 'US Airways',
#     'airline_sentiment': 'negative',
#     'airline_sentiment_confidence': Decimal128('1.0'),
#     'name': 'OBJ_3',
#     'negativereason': 'Late Flight',
#     'negativereason_confidence': Decimal128('1.0'),
#     'retweet_count': 44,
#     'text': '@USAirways 5 hr flight delay and a delay when we land . Is that '
#             'even real life ? Get me off this plane , I wanna go home 👠👠👠 (3 '
#             'heel clicks)',
#     'tweet_created': '2015-02-17 20:06:21 -0800',
#     'tweet_id': 567897883875217408,
#     'user_timezone': 'Eastern Time (US & Canada)'}

# %%
# Example filter to retrieve tweets with at least one retweet
filter={
    'user_timezone': {"$regex": "America"}} #para buscar zonas que contengan America

result = client['AnalisisdeDatos']['Tweets'].find(
  filter=filter)

pp=pprint.PrettyPrinter(indent=4)
for doc in result:
  pp.pprint(doc)
  print("\n")
# Out:
# {   '_id': ObjectId('68770bcab04d7a911987af4f'),
#     'airline': 'Virgin America',
#     'airline_sentiment': 'positive',
#     'airline_sentiment_confidence': Decimal128('1.0'),
#     'name': 'HyperCamiLax',
#     'retweet_count': 0,
#     'text': '@VirginAmerica I &lt;3 pretty graphics. so much better than '
#             'minimal iconography. :D',
#     'tweet_created': '2015-02-24 10:30:40 -0800',
#     'tweet_id': 570289724453216256,
#     'tweet_location': 'NYC',
#     'user_timezone': 'America/New_York'}
#
#
# {   '_id': ObjectId('68770bcab04d7a911987af50'),
#     'airline': 'Virgin America',
#     'airline_sentiment': 'positive',
#     'airline_sentiment_confidence': Decimal128('1.0'),
#     'name': 'HyperCamiLax',
#     'retweet_count': 0,
#     'text': '@VirginAmerica This is such a great deal! Already thinking about '
#             "my 2nd trip to @Australia &amp; I haven't even gone on my 1st "
#             'trip yet! ;p',
# ...

# %%
filter={
    'airline': 'Southwest'} 

result = client['AnalisisdeDatos']['Tweets'].find(
  filter=filter)

pp=pprint.PrettyPrinter(indent=4)
for doc in result:
  pp.pprint(doc)
  print("\n")
# Out:
# {   '_id': ObjectId('68770c52b04d7a911987c02a'),
#     'airline': 'Southwest',
#     'airline_sentiment': 'negative',
#     'airline_sentiment_confidence': Decimal128('1.0'),
#     'name': 'thisradlove',
#     'negativereason': 'longlines',
#     'negativereason_confidence': Decimal128('0.6624'),
#     'retweet_count': 0,
#     'text': '@SouthwestAir still waiting. Just hit one hour.',
#     'tweet_created': '2015-02-24 11:47:53 -0800',
#     'tweet_id': 570309156290367488,
#     'tweet_location': "Today I'm in: Maryland ",
#     'user_timezone': 'Atlantic Time (Canada)'}
#
#
# {   '_id': ObjectId('68770c52b04d7a911987c02b'),
#     'airline': 'Southwest',
#     'airline_sentiment': 'negative',
#     'airline_sentiment_confidence': Decimal128('0.6361'),
#     'name': 'tomcblock',
#     'negativereason': 'Cancelled Flight',
#     'negativereason_confidence': Decimal128('0.6361'),
#     'retweet_count': 0,
#     'text': "@SouthwestAir although I'm not happy you Cancelled Flighted my "
# ...

# %%
filter={
    'airline': 'Virgin America'} 

result = client['AnalisisdeDatos']['Tweets'].find(
  filter=filter)

pp=pprint.PrettyPrinter(indent=4)
for doc in result:
  pp.pprint(doc)
  print("\n")
# Out:
# {   '_id': ObjectId('68770bcab04d7a911987af44'),
#     'airline': 'Virgin America',
#     'airline_sentiment': 'neutral',
#     'airline_sentiment_confidence': Decimal128('1.0'),
#     'name': 'cairdin',
#     'retweet_count': 0,
#     'text': '@VirginAmerica What @dhepburn said.',
#     'tweet_created': '2015-02-24 11:35:52 -0800',
#     'tweet_id': 570306133677760513,
#     'user_timezone': 'Eastern Time (US & Canada)'}
#
#
# {   '_id': ObjectId('68770bcab04d7a911987af45'),
#     'airline': 'Virgin America',
#     'airline_sentiment': 'positive',
#     'airline_sentiment_confidence': Decimal128('0.3486'),
#     'name': 'jnardino',
#     'negativereason_confidence': Decimal128('0.0'),
#     'retweet_count': 0,
#     'text': "@VirginAmerica plus you've added commercials to the experience... "
#             'tacky.',
#     'tweet_created': '2015-02-24 11:15:59 -0800',
#     'tweet_id': 570301130888122368,
#     'user_timezone': 'Pacific Time (US & Canada)'}
#
#
# ...

# %%
#cambiar la estructura de 1000 tweets
db = client['AnalisisdeDatos']
tweets_original = db['Tweets']
cursor = list(tweets_original.find({}, limit=1000))
# Out:
# Se encontraron 1000 tweets.

# %%
def transformar_tweet(tweet):
    return {
        "usuario": {
            "id": tweet.get("tweet_id"),  # cambia esto si tienes otro campo para ID
            "zona_horaria": tweet.get("user_timezone")
        },
        "contenido": tweet.get("text"),
        "motivo_negativo": tweet.get("negativereason"),
        "sentimiento": tweet.get("airline_sentiment"),
        "aerolinea": tweet.get("airline"),
        "es_retweet": tweet.get("retweet_count", 0) > 0
    }

# %%
nueva_estructura = [transformar_tweet(doc) for doc in cursor]

nueva_coleccion = db['TweetsEstructurados']
nueva_coleccion.insert_many(nueva_estructura)
from pprint import pprint

for doc in db['TweetsEstructurados'].find().limit(3):
    pprint(doc)
# Out:
# {'_id': ObjectId('68774aaa4856dbbac2477e05'),
#  'contenido': None,
#  'es_retweet': False,
#  'motivo_negativo': None,
#  'sentimiento': None,
#  'usuario': {'id': None, 'zona_horaria': None}}
# {'_id': ObjectId('68774aaa4856dbbac2477e06'),
#  'contenido': '@VirginAmerica What @dhepburn said.',
#  'es_retweet': False,
#  'motivo_negativo': None,
#  'sentimiento': 'neutral',
#  'usuario': {'id': 570306133677760513,
#              'zona_horaria': 'Eastern Time (US & Canada)'}}
# {'_id': ObjectId('68774aaa4856dbbac2477e07'),
#  'contenido': "@VirginAmerica plus you've added commercials to the "
#               'experience... tacky.',
#  'es_retweet': False,
#  'motivo_negativo': None,
#  'sentimiento': 'positive',
#  'usuario': {'id': 570301130888122368,
#              'zona_horaria': 'Pacific Time (US & Canada)'}}

# %%
filter={'$and': [
    {'negativereason': 'Customer Service Issue'} , {'airline': 'United'}, {'retweet_count': {"$gte": 1}}]}

result = client['AnalisisdeDatos']['Tweets'].find(
  filter=filter)

for doc in result:
  pp.pprint(doc)
  print("\n")
# Out:
# {   '_id': ObjectId('68770bcab04d7a911987b14b'),
#     'airline': 'United',
#     'airline_sentiment': 'negative',
#     'airline_sentiment_confidence': Decimal128('1.0'),
#     'name': 'CheerTymeDad',
#     'negativereason': 'Customer Service Issue',
#     'negativereason_confidence': Decimal128('0.66'),
#     'retweet_count': 1,
#     'text': '@united @CheerTymeDad So I can buy tix 3 days before flight but '
#             "can't transfer the tix.  Flawed security logic. Flawed customer "
#             'service',
#     'tweet_created': '2015-02-24 11:07:12 -0800',
#     'tweet_id': 570298918971576320}
#
#
# {   '_id': ObjectId('68770bcab04d7a911987b17c'),
#     'airline': 'United',
#     'airline_sentiment': 'negative',
#     'airline_sentiment_confidence': Decimal128('1.0'),
#     'name': 'CheerTymeDad',
#     'negativereason': 'Customer Service Issue',
#     'negativereason_confidence': Decimal128('0.3551'),
#     'retweet_count': 1,
# ...

# %%
filter={'$or': [
    {'airline_sentiment': 'positive'} , {'airline': 'American'}, {'airline': 'Southwest'}]}

result = client['AnalisisdeDatos']['Tweets'].find(
  filter=filter)

for doc in result:
  pp.pprint(doc)
  print("\n")
# Out:
# {   '_id': ObjectId('68770bcab04d7a911987af45'),
#     'airline': 'Virgin America',
#     'airline_sentiment': 'positive',
#     'airline_sentiment_confidence': Decimal128('0.3486'),
#     'name': 'jnardino',
#     'negativereason_confidence': Decimal128('0.0'),
#     'retweet_count': 0,
#     'text': "@VirginAmerica plus you've added commercials to the experience... "
#             'tacky.',
#     'tweet_created': '2015-02-24 11:15:59 -0800',
#     'tweet_id': 570301130888122368,
#     'user_timezone': 'Pacific Time (US & Canada)'}
#
#
# {   '_id': ObjectId('68770bcab04d7a911987af4a'),
#     'airline': 'Virgin America',
#     'airline_sentiment': 'positive',
#     'airline_sentiment_confidence': Decimal128('0.6745'),
#     'name': 'cjmcginnis',
#     'negativereason_confidence': Decimal128('0.0'),
#     'retweet_count': 0,
#     'text': '@VirginAmerica yes, nearly every time I fly VX this “ear worm” '
#             'won’t go away :)',
# ...
